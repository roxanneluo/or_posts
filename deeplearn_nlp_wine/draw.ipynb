# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  

percentages = [0, 0.1, 0.2, 0.5, 1]
accuracies = [28.02, 28.99,30.19,30.68,27.29]
plt.plot(percentages, accuracies, 'bo-')
